# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
import seaborn as sns
import scipy
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
merged_data = pd.read_csv('/Users/munisabakhromova/Desktop/research/merged_data.csv')

merged_data.head()
# Out:
# /var/folders/f8/xf4k31p91fq6xlyklv8cjx3m0000gn/T/ipykernel_70819/3831768791.py:1: DtypeWarning: Columns (16,62,65,67,68,70,71,74,78,79,80,81,82,83,85,87,89,90,93,95,96,98,100,101,102,103,104,108,109,110,111,112,113,114,115,116,117,119,120,124,125,128,130,136,137,138,141,143,146,147,148,153,158,162,164,165,167,169,170,172,173,174,177,183,185,186,187,188,189,190,191,192,193,194,197,199,200,201,202,203,204,205,207,208,209,210,212,213,214,215,217,220,221,223,225,230,231,232,236,238,239,240,241,244,245,246,247,251,253,255,259,260,261,262,264,266,267,271,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,353,354,355,356,358,365,367,369,370,371,372,373,374,376,377,378,379,380,381,382,383,385,386,388,394,395,396,397,398,399,400,405,406,412,413,414,415,416,417,418,419,420,421,422,428,429,431,432,433,434,435,436,437,438,439,441,446,447,448,449,450,451,456,457,463,464,468,480,481,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,503,521,522,523,524,525,526,527,529,530,531,532,533,534,535,536,537,539,540,541,542,543,545,548,549,550,551,552,553,554,555,556,557,558,559,560,561,562,563,564,565,566,567,568,569,572,574,575,576,578,580,581,585,586,587,593,594,595,596,597,600,601,602,603,606,607,608,609,610,611,612,613,614,615,616,617,618,619,620,623,625,626,627,628,630,631,632,633,634,635,636,637,638,639,640,641,646,649,655,657,658,660,662,663,664,671,672,673,674,675,676,677,678,679,680,681,682,683,684,685,686,688,689,690,691,692,693,694,695,696,697,698,699,700,702,703,705,706,707,710,711,712,715,716,717,718,719,720,721,722,723,724,725,726,727,728,730,731,732,733,734,735,736,738) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_data = pd.read_csv('/Users/munisabakhromova/Desktop/research/merged_data.csv')
#   country isocode   ison region language        date        id_gallup  wgt_x  \
# 0  Turkey     TUR 792.00  Adana  Turkish  2012-03-07 7100800000001.00   0.27
# 1  Turkey     TUR 792.00  Adana  Turkish  2012-03-08 7100800000002.00   0.27
# 2  Turkey     TUR 792.00  Adana  Turkish  2012-03-08 7100800000003.00   0.44
# 3  Turkey     TUR 792.00  Adana  Turkish  2012-03-07 7100800000004.00   1.42
# 4  Turkey     TUR 792.00  Adana  Turkish  2012-03-07 7100800000005.00   0.71
#
#    patience  risktaking  ...  WP9701  WP9702  WP9704       WP98  WP9811  \
# 0      0.05        1.02  ...     NaN     NaN     NaN  Satisfied     NaN
# 1     -0.68        0.39  ...     NaN     NaN     NaN  Satisfied     NaN
# 2      0.32        1.02  ...     NaN     NaN     NaN  Satisfied     NaN
# 3      0.50        1.27  ...     NaN     NaN     NaN  Satisfied     NaN
# 4      0.59        1.12  ...     NaN     NaN     NaN  Satisfied     NaN
#
#    WP9896       WP99  WP9903 YEAR_CALENDAR  YEAR_WAVE
# 0     NaN  Satisfied     NaN          2012       2012
# 1     NaN  Satisfied     NaN          2012       2012
# 2     NaN  Satisfied     NaN          2012       2012
# 3     NaN  Satisfied     NaN          2012       2012
# 4     NaN  Satisfied     NaN          2012       2012
#
# [5 rows x 742 columns]

# %%
num_samples = 1000
fraction = 0.5
pref="patience"

def random_sampling_pref(data, preference, num_samples, fraction):
   
   # Initialize an empty DataFrame to store the results
   df = pd.DataFrame()   
   sampled_data = pd.DataFrame()
   
   # Repeat the sampling process for a specified number of iterations
   for i in range(num_samples):
      # Group by 'country' and sample half of the observations with replacement
      sampled_data = data.groupby("country")[preference].apply(lambda x: x.sample(frac=fraction, replace=True)).reset_index(level=1,drop=True)
      sampled_data.name = f"{preference}_{i+1}"
      
      # Concatenate the sampled data to the result DataFrame
      df = pd.concat([df, sampled_data], axis=1)

   return df

pref_samples = random_sampling_pref(merged_data,preference=pref, num_samples=num_samples, fraction=fraction)
pref_samples
# Out:
#              patience_1  patience_2  patience_3  patience_4  patience_5  \
# Afghanistan        0.78       -0.04       -0.93       -0.04        1.41
# Afghanistan        0.25       -0.42       -0.04       -1.31       -0.04
# Afghanistan       -0.42        0.21       -0.29        0.77       -0.29
# Afghanistan       -0.04       -0.04       -0.04       -0.80       -0.29
# Afghanistan       -0.04       -0.04       -1.31       -0.55       -0.68
# ...                 ...         ...         ...         ...         ...
# Zimbabwe           0.39       -0.04       -0.42       -0.04       -0.17
# Zimbabwe          -0.29       -0.17       -0.04       -0.04       -0.29
# Zimbabwe           0.61       -0.04       -0.04       -0.55       -0.04
# Zimbabwe           2.11       -0.17       -0.68       -0.04       -0.34
# Zimbabwe          -0.04        0.39        0.07       -0.68        0.20
#
#              patience_6  patience_7  patience_8  patience_9  patience_10  ...  \
# Afghanistan       -0.68        0.77       -0.42        1.73        -0.93  ...
# Afghanistan       -0.04       -0.04        0.21       -0.04         0.02  ...
# Afghanistan       -0.05       -1.06       -0.42       -1.19        -0.42  ...
# Afghanistan        0.67       -0.29       -0.17       -0.08        -0.68  ...
# Afghanistan       -0.42       -0.68       -0.93       -0.61        -0.29  ...
# ...                 ...         ...         ...         ...          ...  ...
# Zimbabwe          -0.29       -0.04        0.96       -0.04        -0.55  ...
# Zimbabwe          -0.55       -0.29       -0.42       -0.17        -0.04  ...
# Zimbabwe          -0.04       -1.06       -0.17       -0.42        -0.04  ...
# Zimbabwe          -0.68       -0.04       -0.04       -0.04        -0.29  ...
# Zimbabwe          -0.04       -0.68       -0.04       -0.04        -0.55  ...
#
#              patience_991  patience_992  patience_993  patience_994  \
# Afghanistan          0.90         -0.17         -1.06         -0.29
# Afghanistan         -0.08         -0.04         -0.31          0.68
# Afghanistan         -0.04         -0.04          1.05         -0.55
# Afghanistan          1.32         -0.40         -0.40         -0.55
# Afghanistan         -0.29         -1.06         -0.55          0.95
# ...                   ...           ...           ...           ...
# Zimbabwe            -0.29         -0.29         -0.17         -0.93
# Zimbabwe            -0.55         -0.04         -0.04         -0.04
# Zimbabwe            -0.17         -0.04         -0.04         -0.04
# Zimbabwe            -0.42         -0.68          0.56         -0.93
# Zimbabwe            -0.42         -0.68         -0.04         -0.04
#
#              patience_995  patience_996  patience_997  patience_998  \
# Afghanistan         -1.06          0.06         -0.68         -0.68
# Afghanistan         -0.17         -1.31         -0.10          0.36
# Afghanistan         -0.93          1.05         -1.31         -0.42
# Afghanistan         -0.42         -0.93         -0.68         -0.68
# Afghanistan         -0.29          0.68         -0.42          0.81
# ...                   ...           ...           ...           ...
# Zimbabwe            -0.04         -1.06         -0.29         -0.17
# Zimbabwe             0.61         -0.04          0.02          1.62
# Zimbabwe             1.41         -0.68         -0.68         -0.55
# Zimbabwe            -0.77         -0.04          0.75          0.59
# Zimbabwe            -0.04          0.14         -0.04         -0.04
#
#              patience_999  patience_1000
# Afghanistan          0.51          -0.62
# Afghanistan         -0.17          -0.68
# Afghanistan         -0.42           0.74
# Afghanistan         -0.04          -0.68
# Afghanistan         -1.31           0.14
# ...                   ...            ...
# Zimbabwe            -0.68          -0.93
# Zimbabwe            -0.55          -0.55
# Zimbabwe             0.34          -0.80
# Zimbabwe             0.25          -0.80
# Zimbabwe            -0.42          -0.93
#
# [40172 rows x 1000 columns]

# %%
def generate_pref_measure_sample(data):
    patience_sample = pd.DataFrame(data.reset_index().rename(columns={'index': 'country'}).groupby(['country']).mean())
    return patience_sample
pref_measure_samples = generate_pref_measure_sample(pref_samples)
pref_measure_samples
# Out:
#                 patience_1  patience_2  patience_3  patience_4  patience_5  \
# country
# Afghanistan          -0.21       -0.16       -0.25       -0.19       -0.20
# Algeria               0.12       -0.04        0.05        0.03        0.03
# Argentina            -0.24       -0.25       -0.22       -0.26       -0.22
# Australia             0.76        0.72        0.70        0.69        0.75
# Austria               0.52        0.60        0.47        0.51        0.51
# ...                    ...         ...         ...         ...         ...
# United Kingdom        0.52        0.58        0.58        0.58        0.48
# United States         0.88        0.80        0.84        0.85        0.88
# Venezuela            -0.27       -0.25       -0.26       -0.30       -0.24
# Vietnam               0.09        0.13        0.18        0.15        0.06
# Zimbabwe             -0.20       -0.21       -0.19       -0.21       -0.24
#
#                 patience_6  patience_7  patience_8  patience_9  patience_10  \
# country
# Afghanistan          -0.23       -0.26       -0.27       -0.21        -0.25
# Algeria               0.03        0.01        0.03        0.05         0.12
# Argentina            -0.21       -0.22       -0.28       -0.24        -0.26
# Australia             0.77        0.61        0.65        0.82         0.73
# Austria               0.48        0.58        0.59        0.54         0.60
# ...                    ...         ...         ...         ...          ...
# United Kingdom        0.57        0.52        0.51        0.60         0.59
# United States         0.91        0.85        0.84        0.87         0.92
# Venezuela            -0.28       -0.30       -0.24       -0.22        -0.19
# Vietnam               0.12        0.16        0.10        0.07         0.14
# Zimbabwe             -0.19       -0.21       -0.25       -0.20        -0.23
#
#                 ...  patience_991  patience_992  patience_993  patience_994  \
# country         ...
# Afghanistan     ...         -0.18         -0.19         -0.18         -0.20
# Algeria         ...          0.10          0.07          0.13          0.10
# Argentina       ...         -0.21         -0.26         -0.30         -0.23
# Australia       ...          0.79          0.65          0.63          0.62
# Austria         ...          0.52          0.56          0.52          0.49
# ...             ...           ...           ...           ...           ...
# United Kingdom  ...          0.61          0.51          0.54          0.54
# United States   ...          0.86          0.88          0.98          0.88
# Venezuela       ...         -0.28         -0.20         -0.21         -0.24
# Vietnam         ...          0.11          0.08          0.11          0.13
# Zimbabwe        ...         -0.21         -0.27         -0.18         -0.19
#
#                 patience_995  patience_996  patience_997  patience_998  \
# country
# Afghanistan            -0.23         -0.20         -0.25         -0.20
# Algeria                -0.00          0.11         -0.01          0.15
# Argentina              -0.21         -0.20         -0.28         -0.24
# Australia               0.71          0.70          0.71          0.75
# Austria                 0.60          0.49          0.60          0.57
# ...                      ...           ...           ...           ...
# United Kingdom          0.55          0.55          0.54          0.53
# United States           0.81          0.86          0.88          0.97
# Venezuela              -0.30         -0.25         -0.26         -0.31
# Vietnam                 0.11          0.15          0.11          0.11
# Zimbabwe               -0.26         -0.21         -0.23         -0.15
#
#                 patience_999  patience_1000
# country
# Afghanistan            -0.21          -0.19
# Algeria                 0.08           0.06
# Argentina              -0.27          -0.26
# Australia               0.71           0.72
# Austria                 0.60           0.59
# ...                      ...            ...
# United Kingdom          0.52           0.57
# United States           0.92           0.85
# Venezuela              -0.20          -0.31
# Vietnam                 0.10           0.09
# Zimbabwe               -0.20          -0.15
#
# [76 rows x 1000 columns]

# %%
country_level=pd.read_stata('/Users/munisabakhromova/Desktop/research/GPS_Dataset/GPS_dataset_country_level/country.dta')
country_level
# Out:
#            country isocode  patience  risktaking  posrecip  negrecip  \
# 0      Afghanistan     AFG     -0.20        0.12      0.29      0.25
# 1          Algeria     DZA      0.06        0.39     -0.60      0.25
# 2        Argentina     ARG     -0.23        0.04      0.16     -0.14
# 3        Australia     AUS      0.66        0.14      0.07      0.02
# 4          Austria     AUT      0.61       -0.06      0.16     -0.06
# ..             ...     ...       ...         ...       ...       ...
# 71  United Kingdom     GBR      0.54        0.05     -0.04      0.02
# 72   United States     USA      0.81        0.12      0.20      0.01
# 73       Venezuela     VEN     -0.23        0.25      0.05     -0.20
# 74         Vietnam     VNM      0.11       -0.01     -0.27     -0.14
# 75        Zimbabwe     ZWE     -0.24        0.52     -0.16     -0.13
#
#     altruism  trust
# 0       0.17   0.32
# 1      -0.01  -0.18
# 2       0.03  -0.21
# 3       0.16   0.30
# 4      -0.04   0.15
# ..       ...    ...
# 71      0.03   0.23
# 72      0.41   0.15
# 73      0.08   0.11
# 74     -0.16   0.14
# 75     -0.04  -0.51
#
# [76 rows x 8 columns]

# %%
pref_measure_samples1=pd.merge(pref_measure_samples,country_level,how='left',on='country')
pref_measure_samples1
# Out:
#            country  patience_1  patience_2  patience_3  patience_4  \
# 0      Afghanistan       -0.21       -0.16       -0.25       -0.19
# 1          Algeria        0.12       -0.04        0.05        0.03
# 2        Argentina       -0.24       -0.25       -0.22       -0.26
# 3        Australia        0.76        0.72        0.70        0.69
# 4          Austria        0.52        0.60        0.47        0.51
# ..             ...         ...         ...         ...         ...
# 71  United Kingdom        0.52        0.58        0.58        0.58
# 72   United States        0.88        0.80        0.84        0.85
# 73       Venezuela       -0.27       -0.25       -0.26       -0.30
# 74         Vietnam        0.09        0.13        0.18        0.15
# 75        Zimbabwe       -0.20       -0.21       -0.19       -0.21
#
#     patience_5  patience_6  patience_7  patience_8  patience_9  ...  \
# 0        -0.20       -0.23       -0.26       -0.27       -0.21  ...
# 1         0.03        0.03        0.01        0.03        0.05  ...
# 2        -0.22       -0.21       -0.22       -0.28       -0.24  ...
# 3         0.75        0.77        0.61        0.65        0.82  ...
# 4         0.51        0.48        0.58        0.59        0.54  ...
# ..         ...         ...         ...         ...         ...  ...
# 71        0.48        0.57        0.52        0.51        0.60  ...
# 72        0.88        0.91        0.85        0.84        0.87  ...
# 73       -0.24       -0.28       -0.30       -0.24       -0.22  ...
# 74        0.06        0.12        0.16        0.10        0.07  ...
# 75       -0.24       -0.19       -0.21       -0.25       -0.20  ...
#
#     patience_998  patience_999  patience_1000  isocode  patience  risktaking  \
# 0          -0.20         -0.21          -0.19      AFG     -0.20        0.12
# 1           0.15          0.08           0.06      DZA      0.06        0.39
# 2          -0.24         -0.27          -0.26      ARG     -0.23        0.04
# 3           0.75          0.71           0.72      AUS      0.66        0.14
# 4           0.57          0.60           0.59      AUT      0.61       -0.06
# ..           ...           ...            ...      ...       ...         ...
# 71          0.53          0.52           0.57      GBR      0.54        0.05
# 72          0.97          0.92           0.85      USA      0.81        0.12
# 73         -0.31         -0.20          -0.31      VEN     -0.23        0.25
# 74          0.11          0.10           0.09      VNM      0.11       -0.01
# 75         -0.15         -0.20          -0.15      ZWE     -0.24        0.52
#
#     posrecip  negrecip  altruism  trust
# 0       0.29      0.25      0.17   0.32
# 1      -0.60      0.25     -0.01  -0.18
# 2       0.16     -0.14      0.03  -0.21
# 3       0.07      0.02      0.16   0.30
# 4       0.16     -0.06     -0.04   0.15
# ..       ...       ...       ...    ...
# 71     -0.04      0.02      0.03   0.23
# 72      0.20      0.01      0.41   0.15
# 73      0.05     -0.20      0.08   0.11
# 74     -0.27     -0.14     -0.16   0.14
# 75     -0.16     -0.13     -0.04  -0.51
#
# [76 rows x 1008 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming pref_measure_samples and country_level are already defined

# Merge the dataframes
matched_data = pd.merge(pref_measure_samples, country_level, how='left', on='country')

# Sort the data by patience
sorted_data = matched_data.sort_values('patience')

# Create a figure and axis
fig, ax = plt.subplots(figsize=(14, 10))

# Plot the boxplot with x and y switched
boxplot = pref_measure_samples.loc[sorted_data['country']].transpose().boxplot(ax=ax, showfliers=False, patch_artist=True)

# Create a scatter plot with x and y switched
scatter = ax.scatter(range(1, len(sorted_data) + 1), sorted_data['patience'], marker='o', color='red', label='Country mean', zorder=10, s=15)

# Customize the plot
# ax.set_title('Patience', fontsize=16)
ax.set_xlabel('Country', fontsize=14)
ax.set_ylabel('Patience measure', fontsize=14)
ax.set_xticks(range(1, len(sorted_data) + 1))
ax.set_xticklabels(sorted_data['country'], rotation='vertical')  # Rotate the country names vertically

# Modify the legend label font size
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(14)  # Adjust the font size as needed
# Save the plot as a PNG file
plt.savefig('/Users/munisabakhromova/Desktop/figure_1.png', dpi=300, bbox_inches='tight')
# Show the plot
plt.show()

# %%
pref_rank_samples = pd.DataFrame()  
for i in pref_measure_samples.columns:
    if i != 'country':  # Check if the column is not 'country'
        pref_rank_samples[i] = pref_measure_samples[i].rank(ascending=False, method='min')
        pref_rank_samples[i] = pref_rank_samples[i].round().astype(pd.Int8Dtype())
    else:
        pref_rank_samples[i] = pref_measure_samples[i]

pref_rank_samples
# Out:
#                 patience_1  patience_2  patience_3  patience_4  patience_5  \
# country
# Afghanistan             51          45          56          49          50
# Algeria                 22          31          27          28          28
# Argentina               55          57          53          56          52
# Australia                5           5           5           5           5
# Austria                 10           8          10          10          10
# ...                    ...         ...         ...         ...         ...
# United Kingdom          11           9           9           8          11
# United States            3           3           4           3           3
# Venezuela               57          58          57          62          54
# Vietnam                 24          20          21          22          27
# Zimbabwe                49          51          49          51          55
#
#                 patience_6  patience_7  patience_8  patience_9  patience_10  \
# country
# Afghanistan             54          56          57          52           56
# Algeria                 26          29          28          25           23
# Argentina               52          52          58          54           59
# Australia                4           8           6           5            6
# Austria                 11           9           8           9            9
# ...                    ...         ...         ...         ...          ...
# United Kingdom           9          10          11           8           10
# United States            3           3           3           4            3
# Venezuela               59          59          55          53           49
# Vietnam                 22          21          25          24           21
# Zimbabwe                51          51          56          50           52
#
#                 ...  patience_991  patience_992  patience_993  patience_994  \
# country         ...
# Afghanistan     ...            46            48            49            50
# Algeria         ...            24            27            22            25
# Argentina       ...            49            55            59            54
# Australia       ...             5             5             7             7
# Austria         ...            11             9            10            11
# ...             ...           ...           ...           ...           ...
# United Kingdom  ...             9            11             9             9
# United States   ...             3             3             3             3
# Venezuela       ...            59            50            53            55
# Vietnam         ...            22            26            23            22
# Zimbabwe        ...            50            57            48            49
#
#                 patience_995  patience_996  patience_997  patience_998  \
# country
# Afghanistan               54            50            51            50
# Algeria                   31            23            32            20
# Argentina                 53            49            57            54
# Australia                  5             5             5             5
# Austria                    8            10             9             9
# ...                      ...           ...           ...           ...
# United Kingdom            10             9            10            11
# United States              3             3             3             3
# Venezuela                 59            57            52            61
# Vietnam                   23            21            22            24
# Zimbabwe                  57            51            50            47
#
#                 patience_999  patience_1000
# country
# Afghanistan               50             49
# Algeria                   26             26
# Argentina                 57             56
# Australia                  5              5
# Austria                    7              9
# ...                      ...            ...
# United Kingdom             9             10
# United States              3              4
# Venezuela                 47             60
# Vietnam                   24             25
# Zimbabwe                  48             45
#
# [76 rows x 1000 columns]

# %%
country_level['patience_rank'] = country_level['patience'].rank(ascending=False, method='min')
country_level
# Out:
#            country isocode  patience  risktaking  posrecip  negrecip  \
# 0      Afghanistan     AFG     -0.20        0.12      0.29      0.25
# 1          Algeria     DZA      0.06        0.39     -0.60      0.25
# 2        Argentina     ARG     -0.23        0.04      0.16     -0.14
# 3        Australia     AUS      0.66        0.14      0.07      0.02
# 4          Austria     AUT      0.61       -0.06      0.16     -0.06
# ..             ...     ...       ...         ...       ...       ...
# 71  United Kingdom     GBR      0.54        0.05     -0.04      0.02
# 72   United States     USA      0.81        0.12      0.20      0.01
# 73       Venezuela     VEN     -0.23        0.25      0.05     -0.20
# 74         Vietnam     VNM      0.11       -0.01     -0.27     -0.14
# 75        Zimbabwe     ZWE     -0.24        0.52     -0.16     -0.13
#
#     altruism  trust  patience_rank
# 0       0.17   0.32          50.00
# 1      -0.01  -0.18          28.00
# 2       0.03  -0.21          52.00
# 3       0.16   0.30           6.00
# 4      -0.04   0.15           8.00
# ..       ...    ...            ...
# 71      0.03   0.23          10.00
# 72      0.41   0.15           3.00
# 73      0.08   0.11          51.00
# 74     -0.16   0.14          20.00
# 75     -0.04  -0.51          54.00
#
# [76 rows x 9 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming pref_rank_samples and country_level are already defined

# Merge the dataframes
matched_data = pd.merge(pref_rank_samples, country_level, how='left', on='country')

# Sort the data by patience_rank in descending order
sorted_data = matched_data.sort_values('patience_rank', ascending=False)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(14, 10))

# Plot the boxplot with x and y switched
boxplot = pref_rank_samples.loc[sorted_data['country']].transpose().boxplot(ax=ax, showfliers=False, patch_artist=True, bootstrap=100)

# Create a scatter plot with x and y switched
scatter = ax.scatter(sorted_data['patience_rank'], range(1, len(sorted_data) + 1), marker='o', color='red', label='Country mean', zorder=10, s=15)

# Customize the plot
# ax.set_title('Patience', fontsize=16)
ax.set_xlabel('Country', fontsize=14)
ax.set_ylabel('Patience ranking', fontsize=14)
ax.set_xticks(range(1, len(sorted_data) + 1))
ax.set_xticklabels(sorted_data['country'], rotation='vertical')  # Rotate the country names vertically

# Modify the legend label font size
legend = ax.legend()
for text in legend.get_texts():
    text.set_fontsize(14)  # Adjust the font size as needed
plt.savefig('/Users/munisabakhromova/Desktop/figure_2.png', dpi=300, bbox_inches='tight')
# Show the plot
plt.show()
